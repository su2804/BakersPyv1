# %%
#import variables containing cell size

import pickle
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

f = open('/Users/Saransh/Documents/2022.03.03/2022.05.14_re_analyze/cell_sizes/size_etoh.pckl', 'rb')
obj1 = pickle.load(f)
f.close()

f = open('/Users/Saransh/Documents/2022.03.03/2022.05.14_re_analyze/cell_sizes/size_raf.pckl', 'rb')
obj2 = pickle.load(f)
f.close()

f = open('/Users/Saransh/Documents/2022.03.03/2022.05.14_re_analyze/cell_sizes/size_gal.pckl', 'rb')
obj3 = pickle.load(f)
f.close()

f = open('/Users/Saransh/Documents/2022.03.03/2022.05.14_re_analyze/cell_sizes/size_glu.pckl', 'rb')
obj4 = pickle.load(f)
f.close()

f = open('/Users/Saransh/Documents/2022.03.03/2022.05.14_re_analyze/cell_sizes/size_suc.pckl', 'rb')
obj5 = pickle.load(f)
f.close()

# %%
vol_cell_1 = []

l=len(obj1)
print(l)
for i in range(0,l):
    if len(obj1[i])>0:
        if len(obj1[i])==1:
            vol_cell_1.append((4/24)*(np.pi)*obj1[i][0][0]*obj1[i][0][1]*obj1[i][0][1])
        elif len(obj1[i])==2:
            vol_cell_1.append(((4/24)*(np.pi)*obj1[i][0][0]*obj1[i][0][1]*obj1[i][0][1])+((4/24)*(np.pi*obj1[i][1][0]*obj1[i][1][1]*obj1[i][1][1])))
        
vol_cell_2 = []
l=len(obj2)
print(l)
count=0
for i in range(0,l):
    if len(obj2[i])>0:
        if len(obj2[i])==1:
            vol_cell_2.append((4/24)*(np.pi)*obj2[i][0][0]*obj2[i][0][1]*obj2[i][0][1])
            count+=1
        elif len(obj2[i])==2:
            vol_cell_2.append(((4/24)*(np.pi)*obj2[i][0][0]*obj2[i][0][1]*obj2[i][0][1])+((4/24)*(np.pi)*obj2[i][1][0]*obj2[i][1][1]*obj2[i][1][1]))
            count+=1
print(count)
        
vol_cell_3 = []
l=len(obj3)
for i in range(0,l):
    if len(obj3[i])>0:
        if len(obj3[i])==1:
            vol_cell_3.append((4/24)*(np.pi)*obj3[i][0][0]*obj3[i][0][1]*obj3[i][0][1])
        elif len(obj3[i])==2:
            vol_cell_3.append(((4/24)*(np.pi)*obj3[i][0][0]*obj3[i][0][1]*obj3[i][0][1])+((4/24)*(np.pi*obj3[i][1][0]*obj3[i][1][1]*obj3[i][1][1])))
                            
        else:
            vol_cell_3.append(0)
vol_cell_4 = []
l=len(obj4)
for i in range(0,l):
    if len(obj4[i])>0:
        if len(obj4[i])==1:
            vol_cell_4.append((4/24)*(np.pi)*obj4[i][0][0]*obj4[i][0][1]*obj4[i][0][1])
        elif len(obj4[i])==2:
            vol_cell_4.append(((4/24)*(np.pi)*obj4[i][0][0]*obj4[i][0][1]*obj4[i][0][1])+((4/24)*(np.pi)*obj4[i][1][0]*obj4[i][1][1]*obj4[i][1][1]))
        
vol_cell_5 = []
l=len(obj5)
for i in range(0,l):
    if len(obj5[i])>0:
        if len(obj5[i])==1:
            vol_cell_5.append((4/24)*(np.pi)*obj5[i][0][0]*obj5[i][0][1]*obj5[i][0][1])
        elif len(obj5[i])==2:
            vol_cell_5.append(((4/24)*(np.pi)*obj5[i][0][0]*obj5[i][0][1]*obj5[i][0][1])+((4/24)*(np.pi)*obj5[i][1][0]*obj5[i][1][1]*obj5[i][1][1]))
        
hist1, bin_edges1 = np.histogram(np.array(vol_cell_1)*0.09*0.09*0.09, density=True)
hist2, bin_edges2 = np.histogram(np.array(vol_cell_2)*0.09*0.09*0.09, density=True)
hist3, bin_edges3 = np.histogram(np.array(vol_cell_3)*0.09*0.09*0.09, density=True)
hist4, bin_edges4 = np.histogram(np.array(vol_cell_4)*0.09*0.09*0.09, density=True)
hist5, bin_edges5 = np.histogram(np.array(vol_cell_5)*0.09*0.09*0.09, density=True)

plt.figure()
plt.scatter(bin_edges1[1:],hist1)
plt.plot(bin_edges1[1:],hist1,label='etoh')

plt.scatter(bin_edges2[1:],hist2)
plt.plot(bin_edges2[1:],hist2,label='raf')
plt.scatter(bin_edges3[1:],hist3)
plt.plot(bin_edges3[1:],hist3,label='gal')
plt.scatter(bin_edges4[1:],hist4)
plt.plot(bin_edges4[1:],hist4,label='glu')


plt.legend()
plt.show()
# Out:
# 1063
# 1437
# 1433

# %%
vol_cell_1 = []

l=len(obj1)
for i in range(0,l):

    if len(obj1[i])==1:
        vol_cell_1.append((4/24)*(np.pi)*obj1[i][0][0]*obj1[i][0][1]*obj1[i][0][1])
    elif len(obj1[i])==2:
        vol_cell_1.append(((4/24)*(np.pi)*obj1[i][0][0]*obj1[i][0][1]*obj1[i][0][1])+((4/24)*(np.pi*obj1[i][1][0]*obj1[i][1][1]*obj1[i][1][1])))
    else:
        vol_cell_1.append(0)
vol_cell_2 = []
l=len(obj2)
print(l)

for i in range(0,l):
  
    if len(obj2[i])==1:
        vol_cell_2.append((4/24)*(np.pi)*obj2[i][0][0]*obj2[i][0][1]*obj2[i][0][1])
        count+=1
    elif len(obj2[i])==2:
        vol_cell_2.append(((4/24)*(np.pi)*obj2[i][0][0]*obj2[i][0][1]*obj2[i][0][1])+((4/24)*(np.pi)*obj2[i][1][0]*obj2[i][1][1]*obj2[i][1][1]))
        count+=1
    else:
        vol_cell_2.append(0)

        
vol_cell_3 = []
l=len(obj3)
for i in range(0,l):

    if len(obj3[i])==1:
        vol_cell_3.append((4/24)*(np.pi)*obj3[i][0][0]*obj3[i][0][1]*obj3[i][0][1])
    elif len(obj3[i])==2:
        vol_cell_3.append(((4/24)*(np.pi)*obj3[i][0][0]*obj3[i][0][1]*obj3[i][0][1])+((4/24)*(np.pi*obj3[i][1][0]*obj3[i][1][1]*obj3[i][1][1])))
    else:
        vol_cell_3.append(0)
        
                
vol_cell_4 = []
l=len(obj4)
for i in range(0,l):
    
    if len(obj4[i])==1:
        vol_cell_4.append((4/24)*(np.pi)*obj4[i][0][0]*obj4[i][0][1]*obj4[i][0][1])
    elif len(obj4[i])==2:
        vol_cell_4.append(((4/24)*(np.pi)*obj4[i][0][0]*obj4[i][0][1]*obj4[i][0][1])+((4/24)*(np.pi)*obj4[i][1][0]*obj4[i][1][1]*obj4[i][1][1]))
    else:
        vol_cell_4.append(0)
        
        
vol_cell_5 = []
l=len(obj5)
for i in range(0,l):
 
    if len(obj5[i])==1:
        vol_cell_5.append((4/24)*(np.pi)*obj5[i][0][0]*obj5[i][0][1]*obj5[i][0][1])
    elif len(obj5[i])==2:
        vol_cell_5.append(((4/24)*(np.pi)*obj5[i][0][0]*obj5[i][0][1]*obj5[i][0][1])+((4/24)*(np.pi)*obj5[i][1][0]*obj5[i][1][1]*obj5[i][1][1]))
    else:
        vol_cell_5.append(0)
        
hist1, bin_edges1 = np.histogram(np.array(vol_cell_1)*0.09*0.09*0.09, density=True)
hist2, bin_edges2 = np.histogram(np.array(vol_cell_2)*0.09*0.09*0.09, density=True)
hist3, bin_edges3 = np.histogram(np.array(vol_cell_3)*0.09*0.09*0.09, density=True)
hist4, bin_edges4 = np.histogram(np.array(vol_cell_4)*0.09*0.09*0.09, density=True)
hist5, bin_edges5 = np.histogram(np.array(vol_cell_5)*0.09*0.09*0.09, density=True)

plt.figure()
plt.scatter(bin_edges1[1:],hist1)
plt.plot(bin_edges1[1:],hist1,label='etoh')

plt.scatter(bin_edges2[1:],hist2)
plt.plot(bin_edges2[1:],hist2,label='raf')
plt.scatter(bin_edges3[1:],hist3)
plt.plot(bin_edges3[1:],hist3,label='gal')
plt.scatter(bin_edges4[1:],hist4)
plt.plot(bin_edges4[1:],hist4,label='glu')


plt.legend()
plt.savefig("CellVolume_Distribution.tif",dpi=300)
# Out:
# 1437

# %%
#Mito estimations (from Mito & ER labelled strains)

#Raffinose
import cv2
mito_raf = []
for i in range(1,1438): #going through each cell's mito hstack
    mito=cv2.imread('/Users/Saransh/Documents/2022.03.03/2022.05.14_re_analyze/Raf/mito_segmented/'+str(i)+'.tif',-1)

    
    mito_raf.append(np.count_nonzero(mito))


print(len(mito_raf))
print(len(vol_cell_2))


#EtOH
import cv2
mito_etoh = []
for i in range(1,1064): #going through each cell's mito hstack
    mito=cv2.imread('/Users/Saransh/Documents/2022.03.03/2022.05.14_re_analyze/EtOH/mito_segmented/'+str(i)+'.tif',-1)
    mito_etoh.append(np.count_nonzero(mito))


print(len(mito_etoh))
print(len(vol_cell_1))


#Glu
import cv2
mito_glu = []
for i in range(1,550): #going through each cell's mito hstack
    mito=cv2.imread('/Users/Saransh/Documents/2022.03.03/2022.05.14_re_analyze/Glu/mito_segmented/'+str(i)+'.tif',-1)
    mito_glu.append(np.count_nonzero(mito))


print(len(mito_glu))
print(len(vol_cell_4))


#Gal
import cv2
mito_gal = []
for i in range(1,588): #going through each cell's mito hstack
    mito=cv2.imread('/Users/Saransh/Documents/2022.03.03/2022.05.14_re_analyze/Gal/mito_segmented/'+str(i)+'.tif',-1)
    mito_gal.append(np.count_nonzero(mito))


print(len(mito_gal))
print(len(vol_cell_3))


#Suc
import cv2
mito_suc = []
for i in range(1,1514): #going through each cell's mito hstack
    mito=cv2.imread('/Users/Saransh/Documents/2022.03.03/2022.05.14_re_analyze/Suc/Mitochondria_segmented/'+str(i)+'.tif',-1)
    mito_suc.append((np.count_nonzero(mito)))


print(len(mito_suc))
print(len(vol_cell_5))
# Out:
# 1437
# 1437
# 1063
# 1063
# 549
# 549
# 587
# 587
# 1513
# 1513

# %%
#Organelle content per cell histograms

hist6, bin_edges6 = np.histogram(np.array(mito_etoh)*0.09*0.09*0.33, density=True)
hist7, bin_edges7 = np.histogram(np.array(mito_raf)*0.09*0.09*0.33, density=True)
hist8, bin_edges8 = np.histogram(np.array(mito_gal)*0.09*0.09*0.33, density=True)
hist9, bin_edges9 = np.histogram(np.array(mito_glu)*0.09*0.09*0.33, density=True)


plt.figure()
plt.scatter(bin_edges6[1:],hist6)
plt.plot(bin_edges6[1:],hist6,label='etoh')

plt.scatter(bin_edges7[1:],hist7)
plt.plot(bin_edges7[1:],hist7,label='raf')
plt.scatter(bin_edges8[1:],hist8)
plt.plot(bin_edges8[1:],hist8,label='gal')
plt.scatter(bin_edges9[1:],hist9)
plt.plot(bin_edges9[1:],hist9,label='glu')
#plt.scatter(bin_edges10[1:],hist10)
#plt.plot(bin_edges10[1:],hist10,label='suc')

plt.legend()
plt.savefig("MitoPerCell_Distribution.tif",dpi=300)

# %%
#Organelle content vs Cell Size
print(len(vol_cell_5))
print(len(mito_suc))

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2,sharex=True, sharey=True,figsize=(6,6))

#ax1.scatter(np.array(vol_cell_5)*0.09*0.09*0.09,np.array(mito_suc)*0.09*0.09*0.33,label='suc', s=80, facecolors='none',edgecolors='k')

ax1.scatter(np.array(vol_cell_4)*0.09*0.09*0.09,np.array(mito_glu)*0.09*0.09*0.33,label='glu', s=5, facecolors='none',edgecolors='b')
ax1.legend()
ax2.scatter(np.array(vol_cell_3)*0.09*0.09*0.09,np.array(mito_gal)*0.09*0.09*0.33,label='gal', s=5, facecolors='none',edgecolors='c')
ax2.legend()
ax3.scatter(np.array(vol_cell_2)*0.09*0.09*0.09,np.array(mito_raf)*0.09*0.09*0.33,label='raf', s=5, facecolors='none',edgecolors='r')
ax3.legend()
ax4.scatter(np.array(vol_cell_1)*0.09*0.09*0.09,np.array(mito_etoh)*0.09*0.09*0.33,label='etoh', s=5, facecolors='none',edgecolors='g')
ax4.legend()
plt.savefig("MitovsSize.tif",dpi=300)
# Out:
# 1513
# 1513

# %%
#Mito fraction vs Growth Rate

mito_glu_frac=[]

mito_gal_frac=[]
mito_raf_frac=[]
mito_etoh_frac=[]

l=len(mito_glu)
mito_glu_mat=[]
for i in range(l):
    if (vol_cell_4[i]>0) & (mito_glu[i]>0):
        mito_glu_frac.append(mito_glu[i]/vol_cell_4[i])
        mito_glu_mat.append([mito_glu[i],vol_cell_4[i]])
        

l=len(mito_gal)
mito_gal_mat=[]
for i in range(l):
    if (vol_cell_3[i]>0) & (mito_gal[i]>0):
        mito_gal_frac.append(mito_gal[i]/vol_cell_3[i])
        mito_glu_mat.append([mito_gal[i],vol_cell_3[i]])

l=len(mito_raf)
mito_raf_mat=[]
for i in range(l):
    if (vol_cell_2[i]>0) & (mito_raf[i]>0):
        mito_raf_frac.append(mito_raf[i]/vol_cell_2[i])
        mito_raf_mat.append([mito_raf[i],vol_cell_2[i]])

l=len(mito_etoh)
mito_etoh_mat=[]
for i in range(l):
    if (vol_cell_1[i]>0) & (mito_etoh[i]>(10/(0.09*0.09*0.33))):
        mito_etoh_frac.append(mito_etoh[i]/vol_cell_1[i])
        mito_etoh_mat.append([mito_etoh[i],vol_cell_1[i]])


        
plt.figure()
plt.errorbar([0.07,0.12,0.3,0.36],[np.median(mito_etoh_frac),np.median(mito_raf_frac),np.median(mito_gal_frac),np.median(mito_glu_frac)],[np.std(mito_etoh_frac),np.std(mito_raf_frac),np.std(mito_gal_frac),np.std(mito_glu_frac)])
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
#ER estimations (from Mito & ER labelled strains)

#Raffinose
import cv2
er_raf = []
for i in range(1,1438): #going through each cell's mito hstack
    er=cv2.imread('/Users/Saransh/Documents/2022.03.03/2022.05.14_re_analyze/Raf/ER_segmented/'+str(i)+'.tif',-1)

    
    er_raf.append(np.count_nonzero(er))


print(len(er_raf))
print(len(vol_cell_2))


#EtOH
import cv2
er_etoh = []
for i in range(1,1064): #going through each cell's mito hstack
    er=cv2.imread('/Users/Saransh/Documents/2022.03.03/2022.05.14_re_analyze/EtOH/ER_segmented/'+str(i)+'.tif',-1)
    er_etoh.append(np.count_nonzero(er))


print(len(er_etoh))
print(len(vol_cell_1))


#Glu
import cv2
er_glu = []
for i in range(1,550): #going through each cell's mito hstack
    er=cv2.imread('/Users/Saransh/Documents/2022.03.03/2022.05.14_re_analyze/Glu/ER_segmented/'+str(i)+'.tif',-1)
    er_glu.append(np.count_nonzero(er))


print(len(er_glu))
print(len(vol_cell_4))


#Gal
import cv2
er_gal = []
for i in range(1,588): #going through each cell's mito hstack
    er=cv2.imread('/Users/Saransh/Documents/2022.03.03/2022.05.14_re_analyze/Gal/ER_segmented/'+str(i)+'.tif',-1)
    er_gal.append(np.count_nonzero(er))


print(len(er_gal))
print(len(vol_cell_3))


#Suc
import cv2
er_suc = []
for i in range(1,1514): #going through each cell's mito hstack
    er=cv2.imread('/Users/Saransh/Documents/2022.03.03/2022.05.14_re_analyze/Suc/ER_segmented/'+str(i)+'.tif',-1)
    er_suc.append((np.count_nonzero(er)))


print(len(er_suc))
print(len(vol_cell_5))
# Out:
# 1437
# 1437
# 1063
# 1063
# 549
# 549
# 587
# 587
# 1513
# 1513

# %%
#Organelle content per cell histograms

hist10, bin_edges10 = np.histogram(np.array(er_etoh)*0.09*0.09*0.33, density=True)
hist11, bin_edges11 = np.histogram(np.array(er_raf)*0.09*0.09*0.33, density=True)
#hist12, bin_edges12 = np.histogram(np.array(er_gal<(40/0.09*0.09*0.33)*0.09*0.09*0.33, density=True))
hist13, bin_edges13 = np.histogram(np.array(er_glu)*0.09*0.09*0.33, density=True)


plt.figure()
plt.scatter(bin_edges10[1:],hist10)
plt.plot(bin_edges10[1:],hist10,label='etoh')

plt.scatter(bin_edges11[1:],hist11)
plt.plot(bin_edges11[1:],hist11,label='raf')
#plt.scatter(bin_edges12[1:],hist12)
#plt.plot(bin_edges12[1:],hist12,label='gal')
plt.scatter(bin_edges13[1:],hist13)
plt.plot(bin_edges13[1:],hist13,label='glu')
#plt.scatter(bin_edges10[1:],hist10)
#plt.plot(bin_edges10[1:],hist10,label='suc')

plt.legend()
plt.savefig("ERPerCell_Distribution.tif",dpi=300)

# %%
#Organelle content vs Cell Size

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2,sharex=True, sharey=True,figsize=(6,6))

#ax1.scatter(np.array(vol_cell_5)*0.09*0.09*0.09,np.array(mito_suc)*0.09*0.09*0.33,label='suc', s=80, facecolors='none',edgecolors='k')

ax1.scatter(np.array(vol_cell_4)*0.09*0.09*0.09,np.array(er_glu)*0.09*0.09*0.33,label='glu', s=5, facecolors='none',edgecolors='b')
ax1.legend()
ax1.set_ylim([0, 40])
ax2.scatter(np.array(vol_cell_3)*0.09*0.09*0.09,np.array(er_gal)*0.09*0.09*0.33,label='gal', s=5, facecolors='none',edgecolors='c')
ax2.legend()
ax3.scatter(np.array(vol_cell_2)*0.09*0.09*0.09,np.array(er_raf)*0.09*0.09*0.33,label='raf', s=5, facecolors='none',edgecolors='r')
ax3.legend()
ax4.scatter(np.array(vol_cell_1)*0.09*0.09*0.09,np.array(er_etoh)*0.09*0.09*0.33,label='etoh', s=5, facecolors='none',edgecolors='g')
ax4.legend()
plt.savefig("ERvsSize.tif",dpi=300)

# %%
#ER fraction vs Growth Rate
import matplotlib
matplotlib.rc('xtick', labelsize=15) 
matplotlib.rc('ytick', labelsize=15) 
matplotlib.rc('ytick', labelsize=15) 
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 15}

matplotlib.rc('font', **font)

er_glu_frac=[]

er_gal_frac=[]
er_raf_frac=[]
er_etoh_frac=[]

l=len(er_glu)
er_glu_mat=[]
for i in range(l):
    if (vol_cell_4[i]>0) and (er_glu[i]>(10/(0.09*0.09*0.33))):
        er_glu_frac.append(er_glu[i]/vol_cell_4[i])
        er_glu_mat.append([er_glu[i],vol_cell_4[i]])
        

l=len(er_gal)
er_gal_mat=[]
for i in range(l):
    if (vol_cell_3[i]>0) and ((er_gal[i]>(10/(0.09*0.09*0.33)) and (er_gal[i]<(50/(0.09*0.09*0.33))))):
        er_gal_frac.append(er_gal[i]/vol_cell_3[i])
        er_glu_mat.append([er_gal[i],vol_cell_3[i]])

l=len(er_raf)
er_raf_mat=[]
for i in range(l):
    if (vol_cell_2[i]>0) and (er_raf[i]>(10/(0.09*0.09*0.33))):
        er_raf_frac.append(er_raf[i]/vol_cell_2[i])
        er_raf_mat.append([er_raf[i],vol_cell_2[i]])

l=len(er_etoh)
er_etoh_mat=[]
for i in range(l):
    if (vol_cell_1[i]>0) and (er_etoh[i]>(10/(0.09*0.09*0.33))):
        er_etoh_frac.append(er_etoh[i]/vol_cell_1[i])
        er_etoh_mat.append([er_etoh[i],vol_cell_1[i]])


        
plt.figure(figsize=(4,4))
plt.errorbar([0.07,0.12,0.3,0.36],[np.median(mito_etoh_frac),np.median(mito_raf_frac),np.median(mito_gal_frac),np.median(mito_glu_frac)],[np.std(mito_etoh_frac),np.std(mito_raf_frac),np.std(mito_gal_frac),np.std(mito_glu_frac)],label="Mitochondria")
plt.errorbar([0.07,0.12,0.3,0.36],[np.median(er_etoh_frac),np.median(er_raf_frac),np.median(er_gal_frac),np.median(er_glu_frac)],[np.std(er_etoh_frac),np.std(er_raf_frac),np.std(er_gal_frac),np.std(er_glu_frac)],label="ER")
plt.ylim([0,0.2])
plt.xlabel("Growth Rate")
plt.ylabel("Volume Fraction")
plt.legend()
plt.savefig("ER_fraction.tif",dpi=300)
